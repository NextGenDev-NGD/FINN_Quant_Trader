# %%
  import pandas as pd                                                                                                  import numpy as np
  import yfinance as yf                                                                                                import matplotlib.pyplot as plt
  import warnings
  warnings.filterwarnings('ignore')

  print("pandas:", pd.__version__)
  print("numpy:", np.__version__)
  print("yfinance:", yf.__version__)
  print("All imports successful.")
# Out:
#   Cell In[1], line 1
#     import pandas as pd                                                                                                  import numpy as np
#                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("yfinance:", yf.__version__)
print("All imports successful.")
# Out:
# pandas: 3.0.2
# numpy: 2.4.4
# yfinance: 1.3.0
# All imports successful.

# %%
 ticker = "SPY"
df = yf.download(ticker, period="1y", interval="1d", progress=False)
df.columns = [c[0] if isinstance(c, tuple) else c for c in df.columns]

print(f"Shape: {df.shape}")
print(f"\nColumn names:\n{df.columns.tolist()}")
print(f"\nFirst 5 rows:\n{df.head()}")
print(f"\nData types:\n{df.dtypes}")
print(f"\nAny nulls?\n{df.isnull().sum()}")
# Out:
#   Cell In[3], line 1
#     ticker = "SPY"
#     ^
# IndentationError: unexpected indent

# %%
  ticker = "SPY"                                                                                                       df = yf.download(ticker, period="1y", interval="1d", progress=False)
  df.columns = [c[0] if isinstance(c, tuple) else c for c in df.columns]

  print(f"Shape: {df.shape}")
  print(f"\nColumn names:\n{df.columns.tolist()}")
  print(f"\nFirst 5 rows:\n{df.head()}")
  print(f"\nData types:\n{df.dtypes}")
  print(f"\nAny nulls?\n{df.isnull().sum()}")
# Out:
#   Cell In[4], line 1
#     ticker = "SPY"                                                                                                       df = yf.download(ticker, period="1y", interval="1d", progress=False)
#                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
 ticker = "SPY"
  df = yf.download(ticker, period="1y", interval="1d", progress=False)
  df.columns = [c[0] if isinstance(c, tuple) else c for c in df.columns]
  print(f"Shape: {df.shape}")
  print(f"\nColumn names:\n{df.columns.tolist()}")
  print(f"\nFirst 5 rows:\n{df.head()}")
  print(f"\nData types:\n{df.dtypes}")
  print(f"\nAny nulls?\n{df.isnull().sum()}")
# Out:
#   Cell In[5], line 2
#     df = yf.download(ticker, period="1y", interval="1d", progress=False)
#     ^
# IndentationError: unexpected indent

# %%
 ticker = "SPY"
 df = yf.download(ticker, period="1y", interval="1d", progress=False)
df.columns = [c[0] if isinstance(c, tuple) else c for c in df.columns]
 print(f"Shape: {df.shape}")
# Out:
#   Cell In[6], line 1
#     ticker = "SPY"
#     ^
# IndentationError: unexpected indent

# %%
ticker = "SPY"
  df = yf.download(ticker, period="1y", interval="1d", progress=False)
  df.columns = [c[0] if isinstance(c, tuple) else c for c in df.columns]
  print(f"Shape: {df.shape}")
  print(f"\nColumn names:\n{df.columns.tolist()}")
  print(f"\nFirst 5 rows:\n{df.head()}")
  print(f"\nData types:\n{df.dtypes}")
  print(f"\nAny nulls?\n{df.isnull().sum()}")
# Out:
#   Cell In[9], line 2
#     df = yf.download(ticker, period="1y", interval="1d", progress=False)
#     ^
# IndentationError: unexpected indent

# %%
ticker = "SPY"
df = yf.download(ticker, period="1y", interval="1d", progress=False)
df.columns = [c[0] if isinstance(c, tuple) else c for c in df.columns]
print(f"Shape: {df.shape}")
print(df.head())
# Out:
# Shape: (251, 5)
#                  Close        High         Low        Open    Volume
# Date
# 2025-04-21  508.055847  515.787225  502.697263  515.253307  69368100
# 2025-04-22  521.274353  523.301107  513.305704  514.244949  75948100
# 2025-04-23  529.351746  539.248306  527.829221  534.304974  90590700
# 2025-04-24  540.493958  541.225561  529.381358  530.636924  64150400
# 2025-04-25  544.399292  544.804619  537.528048  540.454523  61119600

# %%
print(df.describe())
print(f"Highest close: ${df['Close'].max():.2f}")
print(f"Lowest close: ${df['Close'].min():.2f}")
print(f"Average volume: {df['Volume'].mean():,.0f} shares/day")
# Out:
#             Close        High         Low        Open        Volume
# count  251.000000  251.000000  251.000000  251.000000  2.510000e+02
# mean   646.172765  648.972752  642.624343  645.885819  7.690565e+07
# std     41.722763   41.775843   41.873083   41.959798  2.152540e+07
# min    508.055847  515.787225  502.697263  514.244949  2.531848e+07
# 25%    622.722900  624.304494  620.620766  622.861774  6.300670e+07
# 50%    658.878357  661.990657  654.716628  658.450831  7.278010e+07
# 75%    679.491028  681.973596  676.035687  679.443101  8.893890e+07
# max    710.140015  712.390015  706.140015  708.780029  1.652935e+08
# Highest close: $710.14
# Lowest close: $508.06
# Average volume: 76,905,650 shares/day

# %%
df['Daily_Return'] = df['Close'].pct_change()
print(df[['Close', 'Daily_Return']].head(10))
print(f"Mean daily return: {df['Daily_Return'].mean():.4f}")
print(f"Best day: {df['Daily_Return'].max():.2%}")
print(f"Worst day: {df['Daily_Return'].min():.2%}")
# Out:
#                  Close  Daily_Return
# Date
# 2025-04-21  508.055847           NaN
# 2025-04-22  521.274353      0.026018
# 2025-04-23  529.351746      0.015495
# 2025-04-24  540.493958      0.021049
# 2025-04-25  544.399292      0.007225
# 2025-04-28  544.606873      0.000381
# 2025-04-29  548.037537      0.006299
# 2025-04-30  548.255005      0.000397
# 2025-05-01  552.140503      0.007087
# 2025-05-02  560.336487      0.014844
# Mean daily return: 0.0014
# Best day: 3.30%
# Worst day: -2.70%

# %%
max_vol_date = df['Volume'].idxmax()
max_vol_row = df.loc[max_vol_date]
print(f"Highest volume day: {max_vol_date.date()}")
print(f"Volume: {max_vol_row['Volume']:,.0f}")
print(f"Close that day: ${max_vol_row['Close']:.2f}")
print(f"Return that day: {max_vol_row['Daily_Return']:.2%}")
# Out:
# Highest volume day: 2025-11-20
# Volume: 165,293,500
# Close that day: $648.84
# Return that day: -1.52%

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
ax1.plot(df.index, df['Close'], color='steelblue', linewidth=1.5)
ax1.set_title(f'{ticker} — 1 Year Closing Price', fontsize=14)
ax1.set_ylabel('Price ($)')
ax1.grid(True, alpha=0.3)
ax2.bar(df.index, df['Volume'], color='gray', alpha=0.6)
ax2.set_title(f'{ticker} — Daily Volume', fontsize=14)
ax2.set_ylabel('Volume (shares)')
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
#       2 ax1.plot(df.index, df['Close'], color='steelblue', linewidth=1.5)
#       3 ax1.set_title(f'{ticker} — 1 Year Closing Price', fontsize=14)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
ax1.plot(df.index, df['Close'], color='steelblue', linewidth=1.5)
ax1.set_title(f'{ticker} — 1 Year Closing Price', fontsize=14)
ax1.set_ylabel('Price ($)')
ax1.grid(True, alpha=0.3)
ax2.bar(df.index, df['Volume'], color='gray', alpha=0.6)
ax2.set_title(f'{ticker} — Daily Volume', fontsize=14)
ax2.set_ylabel('Volume (shares)')
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
tickers = ['QQQ', 'TSLA', 'BTC-USD', 'GLD']
results = {}
for t in tickers:
    data = yf.download(t, period="1y", interval="1d", progress=False)
    data.columns = [c[0] if isinstance(c, tuple) else c for c in data.columns]
    data['Daily_Return'] = data['Close'].pct_change()
    results[t] = data
print("Done. Tickers loaded:", list(results.keys()))
# Out:
# Done. Tickers loaded: ['QQQ', 'TSLA', 'BTC-USD', 'GLD']

# %%
for t, data in results.items():                                                                                                                                                                                                                                  for t, data in results.items():
    avg_vol = data['Volume'].mean()                                                                                                                                                                                                                        avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    worst_date = data['Daily_Return'].idxmin()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
#   Cell In[18], line 1
#     for t, data in results.items():                                                                                                                                                                                                                                  for t, data in results.items():
#                                                                                                                                                                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
for t, data in results.items():                                                                                                                                                                                                             avg_vol = data['Volume'].mean()
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
#   Cell In[19], line 2
#     avg_vol = data['Volume'].mean()
#     ^
# IndentationError: unexpected indent

# %%
for t, data in results.items():                                                                                                                                                                                                             avg_vol = data['Volume'].mean()
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
#   Cell In[20], line 2
#     avg_vol = data['Volume'].mean()
#     ^
# IndentationError: unexpected indent

# %%
for t, data in results.items():                                                                                                                                                                                                             avg_vol = data['Volume'].mean()
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
#   Cell In[21], line 2
#     avg_vol = data['Volume'].mean()
#     ^
# IndentationError: unexpected indent

# %%
for t, data in results.items():                                                                                                                                                                                       avg_vol = data['Volume'].mean()
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
#   Cell In[22], line 2
#     avg_vol = data['Volume'].mean()
#     ^
# IndentationError: unexpected indent

# %%
for t, data in results.items():
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_return'].min()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\finnenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Daily_return'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 4
#       2 avg_vol = data['Volume'].mean()
# ...

# %%
for t, data in results.items():                                                                                                                                                                                       avg_vol = data['Volume'].mean()
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
#   Cell In[24], line 2
#     avg_vol = data['Volume'].mean()
#     ^
# IndentationError: unexpected indent

# %%
for t,data in results.items():
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 6
#       4 worst = data['Daily_Return'].min()
#       5 max_vol_date = data['Volume'].idxmax()
# ----> 6 print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
#
# NameError: name 'worst_date' is not defined

# %%
 for t, data in results.items():
    avg_vol = data['Volume'].mean()
    std_ret = data['Daily_Return'].std()
    worst = data['Daily_Return'].min()
    worst_date = data['Daily_Return'].idxmin()
    max_vol_date = data['Volume'].idxmax()
    print(f"{t} | Avg Vol: {avg_vol:,.0f} | Std: {std_ret:.4f} | Worst day: {worst:.2%} on {worst_date.date()} | Max vol date: {max_vol_date.date()}")
# Out:
# QQQ | Avg Vol: 53,911,581 | Std: 0.0105 | Worst day: -3.47% on 2025-10-10 | Max vol date: 2025-11-20
# TSLA | Avg Vol: 85,080,961 | Std: 0.0307 | Worst day: -14.26% on 2025-06-05 | Max vol date: 2025-06-05
# BTC-USD | Avg Vol: 52,844,550,700 | Std: 0.0227 | Worst day: -14.13% on 2026-02-05 | Max vol date: 2025-07-14
# GLD | Avg Vol: 14,023,952 | Std: 0.0172 | Worst day: -10.27% on 2026-01-30 | Max vol date: 2026-01-30

# %% [markdown]
#   Q1 — Highest average daily volume: TSLA at 85 million shares/day (BTC-USD volume is in dollars, not shares — not comparable directly to equities).
#   Q2 — Most volatile daily returns: TSLA with std of 0.0307 — nearly 3x more volatile than SPY (0.0083). One typical TSLA day moves ±3%.
#   Q3 — Worst single day across all 5: TSLA at -14.26% on June 5, 2025. That's a significant single-day crash — worth researching what happened.
#
#   Q4 — Volume/price relationship: You'll answer this visually after we plot them.
#
#   Q5 — Highest volume day research: TSLA's max volume day is the same as its worst day — June 5, 2025. That's a strong signal. Look up what happened to TSLA on that date.

# %%
for t, data in results.items():
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
    ax1.plot(data.index, data['Close'], color='steelblue', linewidth=1.5)
    ax1.set_title(f'{t} — 1 Year Closing Price', fontsize=14)
    ax1.set_ylabel('Price ($)')
    ax1.grid(True, alpha=0.3)
    ax2.bar(data.index, data['Volume'], color='gray', alpha=0.6)
    ax2.set_title(f'{t} — Daily Volume', fontsize=14)
    ax2.set_ylabel('Volume')
    ax2.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
